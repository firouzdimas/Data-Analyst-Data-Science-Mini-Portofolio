# %% [markdown]
# <a href="https://colab.research.google.com/github/firouzdimas/Data-Analyst-Data-Science-Mini-Portofolio/blob/main/NgabuburIT_Data_Ramadhan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---

# %% [markdown]
# ## Data Collection / Exploration
#
# `- Collect data from different sources` <br>
# `- Data exploration using popular Python module` <br>
# `- SQL Queries`

# %% [markdown]
# The iris taxanomic dataset is for folks practicing basic machine learning (ML) algorithms. It sampled 50 each of the following three (3) iris flower species as data classes:
#
# - Iris setosa
# - Iris versicolor
# - Iris virginica.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Reading from CSV (IRIS)

# %% [markdown]
# You can read data from a CSV file using the `read_csv` function. By default, it assumes that the fields are comma-separated.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/My Drive/Celerates School/
# Out:
# /content/drive/My Drive/Celerates School

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import matplotlib

iris = pd.read_csv(r'IRIS.csv')
iris.head(5) # membaca 5 row teratas
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# The columns in the given iris dataset are:
#
# - SepalLengthCm
# - SepalWidthCm
# - PetalLengthCm
# - PetalWidthCm
# - Species

# %%
iris.shape # melihat dimensi dari data (row, kolom)
# Out:
# (150, 5)

# %%
iris.isnull().sum() # melihat null value dari tiap kolom, jika output yang keluar adalah angka 0 artinya kolom tersebut tidak memiliki nilai null
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.info() # memperlihatkan info umum dari dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe() # memperlihatkan beberapa info statistik umum dari dataframe
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris['species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%'
                                        ,shadow=True, figsize=(4,4))
plt.show() # melihat jumlah spesies untuk setiap kelas menggunakan pie chart

# %%
sns.FacetGrid(iris, hue="species") \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend()

# %%
sns.FacetGrid(iris, hue="species") \
   .map(plt.scatter, "petal_length", "petal_width") \
   .add_legend()

# %%
ax = sns.boxplot(x="species", y="petal_length", data=iris)
ax = sns.stripplot(x="species", y="petal_length", data=iris, jitter=True, edgecolor="gray")

# %%
sns.pairplot(iris , hue='species');

# %% [markdown]
# ### Selecting data & finding the most common complaint type

# %%
complaints = pd.read_csv('311-service-requests.csv')
complaints.head(5)
# Out:
# <ipython-input-10-0c926e2008ff>:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   complaints = pd.read_csv('311-service-requests.csv')
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# ...

# %% [markdown]
# #### Selecting columns and rows

# %%
# To select a column, we index with the name of the column
complaints['Complaint Type']
# Out:
# 0         Noise - Street/Sidewalk
# 1                 Illegal Parking
# 2              Noise - Commercial
# 3                 Noise - Vehicle
# 4                          Rodent
#                    ...
# 111064    Maintenance or Facility
# 111065            Illegal Parking
# 111066    Noise - Street/Sidewalk
# 111067         Noise - Commercial
# 111068           Blocked Driveway
# Name: Complaint Type, Length: 111069, dtype: object

# %%
#### To get the first 5 rows of a dataframe, we can use a slice: `df[:5]`.
complaints[:5]
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 1    26593698  10/31/2013 02:01:04 AM                     NaN   NYPD
# 2    26594139  10/31/2013 02:00:24 AM  10/31/2013 02:40:32 AM   NYPD
# 3    26595721  10/31/2013 01:56:23 AM  10/31/2013 02:21:48 AM   NYPD
# 4    26590930  10/31/2013 01:53:44 AM                     NaN  DOHMH
#
#                                Agency Name           Complaint Type  \
# 0          New York City Police Department  Noise - Street/Sidewalk
# 1          New York City Police Department          Illegal Parking
# 2          New York City Police Department       Noise - Commercial
# 3          New York City Police Department          Noise - Vehicle
# 4  Department of Health and Mental Hygiene                   Rodent
#
#                      Descriptor        Location Type Incident Zip  \
# 0                  Loud Talking      Street/Sidewalk      11432.0
# ...

# %% [markdown]
# This is a great way to get a sense for what kind of information is in the dataframe -- take a minute to look at the contents and get a feel for this dataset.

# %%
# We can combine these to get the first 5 rows of a column
complaints['Complaint Type'][:5]
# Out:
# 0    Noise - Street/Sidewalk
# 1            Illegal Parking
# 2         Noise - Commercial
# 3            Noise - Vehicle
# 4                     Rodent
# Name: Complaint Type, dtype: object

# %%
# and it doesn't matter which direction we do it in:
complaints[:5]['Complaint Type']
# Out:
# 0    Noise - Street/Sidewalk
# 1            Illegal Parking
# 2         Noise - Commercial
# 3            Noise - Vehicle
# 4                     Rodent
# Name: Complaint Type, dtype: object

# %% [markdown]
# #### Selecting multiple columns
#
# What if we just want to know just some column, but not the rest of the information? Pandas makes it really easy to select a subset of the columns: just index with list of columns you want.

# %%
complaints[['Complaint Type', 'Borough']]
# Out:
#                  Complaint Type    Borough
# 0       Noise - Street/Sidewalk     QUEENS
# 1               Illegal Parking     QUEENS
# 2            Noise - Commercial  MANHATTAN
# 3               Noise - Vehicle  MANHATTAN
# 4                        Rodent  MANHATTAN
# ...                         ...        ...
# 111064  Maintenance or Facility   BROOKLYN
# 111065          Illegal Parking     QUEENS
# 111066  Noise - Street/Sidewalk  MANHATTAN
# 111067       Noise - Commercial   BROOKLYN
# 111068         Blocked Driveway   BROOKLYN
#
# [111069 rows x 2 columns]
# ...

# %%
complaints[['Complaint Type', 'Borough']][:10]

# %% [markdown]
# #### What's the most common complaint type?

# %%
# There's a `.value_counts()` method that we can use to count the value
complaints['Complaint Type'].value_counts()
# Out:
# HEATING                           14200
# GENERAL CONSTRUCTION               7471
# Street Light Condition             7117
# DOF Literature Request             5797
# PLUMBING                           5373
#                                   ...
# Municipal Parking Facility            1
# Tunnel Condition                      1
# DHS Income Savings Requirement        1
# Stalled Sites                         1
# X-Ray Machine/Equipment               1
# Name: Complaint Type, Length: 165, dtype: int64

# %%
# If we just wanted the top 10 most common complaints
complaint_counts = complaints['Complaint Type'].value_counts()
complaint_counts[:10]
# Out:
# HEATING                   14200
# GENERAL CONSTRUCTION       7471
# Street Light Condition     7117
# DOF Literature Request     5797
# PLUMBING                   5373
# PAINT - PLASTER            5149
# Blocked Driveway           4590
# NONCONST                   3998
# Street Condition           3473
# Illegal Parking            3343
# Name: Complaint Type, dtype: int64

# %%
noise_complaints = complaints[complaints['Complaint Type'] == "Noise - Street/Sidewalk"]
noise_complaints[:3]
# Out:
#     Unique Key            Created Date             Closed Date Agency  \
# 0     26589651  10/31/2013 02:08:41 AM                     NaN   NYPD
# 16    26594086  10/31/2013 12:54:03 AM  10/31/2013 02:16:39 AM   NYPD
# 25    26591573  10/31/2013 12:35:18 AM  10/31/2013 02:41:35 AM   NYPD
#
#                         Agency Name           Complaint Type  \
# 0   New York City Police Department  Noise - Street/Sidewalk
# 16  New York City Police Department  Noise - Street/Sidewalk
# 25  New York City Police Department  Noise - Street/Sidewalk
#
#           Descriptor    Location Type Incident Zip     Incident Address  ...  \
# 0       Loud Talking  Street/Sidewalk      11432.0     90-03 169 STREET  ...
# 16  Loud Music/Party  Street/Sidewalk      10310.0  173 CAMPBELL AVENUE  ...
# 25      Loud Talking  Street/Sidewalk      10312.0    24 PRINCETON LANE  ...
#
#    Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                  NaN                      NaN       NaN
# ...

# %%
complaints['Complaint Type'] == "Noise - Street/Sidewalk"
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 111064    False
# 111065    False
# 111066     True
# 111067    False
# 111068    False
# Name: Complaint Type, Length: 111069, dtype: bool

# %%
is_noise = complaints['Complaint Type'] == "Noise - Street/Sidewalk"
in_brooklyn = complaints['Borough'] == "BROOKLYN"
complaints[is_noise & in_brooklyn][:5]
# Out:
#      Unique Key            Created Date             Closed Date Agency  \
# 31     26595564  10/31/2013 12:30:36 AM                     NaN   NYPD
# 49     26595553  10/31/2013 12:05:10 AM  10/31/2013 02:43:43 AM   NYPD
# 109    26594653  10/30/2013 11:26:32 PM  10/31/2013 12:18:54 AM   NYPD
# 236    26591992  10/30/2013 10:02:58 PM  10/30/2013 10:23:20 PM   NYPD
# 370    26594167  10/30/2013 08:38:25 PM  10/30/2013 10:26:28 PM   NYPD
#
#                          Agency Name           Complaint Type  \
# 31   New York City Police Department  Noise - Street/Sidewalk
# 49   New York City Police Department  Noise - Street/Sidewalk
# 109  New York City Police Department  Noise - Street/Sidewalk
# 236  New York City Police Department  Noise - Street/Sidewalk
# 370  New York City Police Department  Noise - Street/Sidewalk
#
#            Descriptor    Location Type Incident Zip    Incident Address  ...  \
# 31   Loud Music/Party  Street/Sidewalk      11236.0            AVENUE J  ...
# ...

# %%
complaints[is_noise & in_brooklyn][['Complaint Type', 'Borough', 'Created Date', 'Descriptor']][:10]
# Out:
#                Complaint Type   Borough            Created Date  \
# 31    Noise - Street/Sidewalk  BROOKLYN  10/31/2013 12:30:36 AM
# 49    Noise - Street/Sidewalk  BROOKLYN  10/31/2013 12:05:10 AM
# 109   Noise - Street/Sidewalk  BROOKLYN  10/30/2013 11:26:32 PM
# 236   Noise - Street/Sidewalk  BROOKLYN  10/30/2013 10:02:58 PM
# 370   Noise - Street/Sidewalk  BROOKLYN  10/30/2013 08:38:25 PM
# 378   Noise - Street/Sidewalk  BROOKLYN  10/30/2013 08:32:13 PM
# 656   Noise - Street/Sidewalk  BROOKLYN  10/30/2013 06:07:39 PM
# 1251  Noise - Street/Sidewalk  BROOKLYN  10/30/2013 03:04:51 PM
# 5416  Noise - Street/Sidewalk  BROOKLYN  10/29/2013 10:07:02 PM
# 5584  Noise - Street/Sidewalk  BROOKLYN  10/29/2013 08:15:59 PM
#
#             Descriptor
# 31    Loud Music/Party
# 49        Loud Talking
# 109   Loud Music/Party
# 236       Loud Talking
# 370   Loud Music/Party
# 378       Loud Talking
# 656   Loud Music/Party
# 1251      Loud Talking
# 5416      Loud Talking
# ...

# %% [markdown]
# #### Try to Query in Python

# %%
# !pip install functions

# %%
# Example python program to read data from a PostgreSQL table

# and load into a pandas DataFrame

import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# Create an engine instance
alchemyEngine   = create_engine('postgresql+psycopg2://coding-ramadhan:;DfKq76<D]lN-R%p@34.101.163.25:5432/codingramadhan');

# Connect to PostgreSQL server
dbConnection    = alchemyEngine.connect(); 

# Read data from PostgreSQL database table and load into a DataFrame instance
store_all       = pd.read_sql("select * from sales.store", dbConnection);
pd.set_option('display.expand_frame_repr', False);

# Print the DataFrame
print(store_all);

# Close the database connection
dbConnection.close();
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144             try:
# --> 145                 self._dbapi_connection = engine.raw_connection()
#     146             except dialect.loaded_dbapi.Error as err:
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/engine/base.py in raw_connection(self)
#    3287         """
# -> 3288         return self.pool.connect()
#    3289
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/pool/base.py in connect(self)
#     451         """
# --> 452         return _ConnectionFairy._checkout(self)
#     453
#
# /usr/local/lib/python3.10/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#    1267         if not fairy:
# ...

# %%
# Example python program to read data from a PostgreSQL table

# and load into a pandas DataFrame

import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# Create an engine instance
alchemyEngine = create_engine('postgresql+psycopg2://coding-ramadhan:;DfKq76<D]lN-R%p@34.101.163.25:5432/codingramadhan');

# Connect to PostgreSQL server
dbConnection = alchemyEngine.connect(); 

# Read data from PostgreSQL database table and load into a DataFrame instance
store       = pd.read_sql("select businessentityid, name from sales.store", dbConnection);
pd.set_option('display.expand_frame_repr', False);

# Print the DataFrame
print(store);

# %%
# Read data from PostgreSQL database table and load into a DataFrame instance
distinct_group = pd.read_sql("select distinct(s.group) from sales.salesterritory s", dbConnection);
pd.set_option('display.expand_frame_repr', False);

# Print the DataFrame
print(distinct_group);
